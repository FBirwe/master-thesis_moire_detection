# %%
import sys
sys.path.append('../../30_data_tools/')
sys.path.append('../process_masks/')

# %%
from PIL import Image

# %%
from helper import load_dotenv
from mask_functions import load_masks

# %%
dotenv = load_dotenv()

# %%
mask_files = list(dotenv['DATA_DIR'].glob(f'./*/halftone{ dotenv["LOFI_DPI"] }dpi/*.pkl'))

# %%
masks = load_masks(mask_files[1])

# %%
sorted(masks, key=lambda m: m['bbox'][0]+m['bbox'][1])
# Out:
# [{'mask': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'bbox': [0, 0, 178, 6726],
#   'predicted_iou': 0.9763707518577576,
#   'stability_score': 0.9559192657470703,
#   'img_size': (4980, 6728)},
#  {'mask': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'bbox': [290, 16, 1298, 140],
#   'predicted_iou': 0.9427841901779175,
# ...

# %%
m = sorted(masks, key=lambda m: m['bbox'][0]+m['bbox'][1])[0]

# %%
Image.fromarray(m['mask'])
# Out:
# <PIL.Image.Image image mode=1 size=172x6468>
